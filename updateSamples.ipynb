# %% [markdown]
# # __Converting font files from svg to png__

# %% [markdown]
# ## Importing all necessary libraries

# %%
import glob;
import aspose.words as aw;

# %% [markdown]
# ## Accessing all font files path

# %%
files = glob.glob("./font/*/*/*.svg");
print(str(len(files)) + " handwritten svg files!", "\n", files, sep="");
# Out:
# 2053 handwritten svg files!
# ['./font/numbers/number_zero/number_zero_7.svg', './font/numbers/number_zero/number_zero_6.svg', './font/numbers/number_zero/number_zero_4.svg', './font/numbers/number_zero/number_zero_5.svg', './font/numbers/number_zero/number_zero_20.svg', './font/numbers/number_zero/number_zero_18.svg', './font/numbers/number_zero/number_zero_1.svg', './font/numbers/number_zero/number_zero_19.svg', './font/numbers/number_zero/number_zero_2.svg', './font/numbers/number_zero/number_zero_3.svg', './font/numbers/number_zero/number_zero_17.svg', './font/numbers/number_zero/number_zero_16.svg', './font/numbers/number_zero/number_zero_14.svg', './font/numbers/number_zero/number_zero_15.svg', './font/numbers/number_zero/number_zero_11.svg', './font/numbers/number_zero/number_zero_8.svg', './font/numbers/number_zero/number_zero_9.svg', './font/numbers/number_zero/number_zero_10.svg', './font/numbers/number_zero/number_zero_12.svg', './font/numbers/number_zero/number_zero_13.svg', './font/numbers/number_two/number_two_1.svg', './font/numbers/number_two/number_two_20.svg', './font/numbers/number_two/number_two_2.svg', './font/numbers/number_two/number_two_3.svg', './font/numbers/number_two/number_two_7.svg', './font/numbers/number_two/number_two_6.svg', './font/numbers/number_two/number_two_18.svg', './font/numbers/number_two/number_two_4.svg', './font/numbers/number_two/number_two_5.svg', './font/numbers/number_two/number_two_19.svg', './font/numbers/number_two/number_two_14.svg', './font/numbers/number_two/number_two_8.svg', './font/numbers/number_two/number_two_9.svg', './font/numbers/number_two/number_two_15.svg', './font/numbers/number_two/number_two_17.svg', './font/numbers/number_two/number_two_16.svg', './font/numbers/number_two/number_two_12.svg', './font/numbers/number_two/number_two_13.svg', './font/numbers/number_two/number_two_11.svg', './font/numbers/number_two/number_two_10.svg', './font/numbers/number_one/number_one_40.svg', './font/numbers/number_one/number_one_8.svg', './font/numbers/number_one/number_one_9.svg', './font/numbers/number_one/number_one_37.svg', './font/numbers/number_one/number_one_23.svg', './font/numbers/number_one/number_one_22.svg', './font/numbers/number_one/number_one_36.svg', './font/numbers/number_one/number_one_20.svg', './font/numbers/number_one/number_one_34.svg', './font/numbers/number_one/number_one_35.svg', './font/numbers/number_one/number_one_21.svg', './font/numbers/number_one/number_one_25.svg', './font/numbers/number_one/number_one_31.svg', './font/numbers/number_one/number_one_19.svg', './font/numbers/number_one/number_one_18.svg', './font/numbers/number_one/number_one_30.svg', './font/numbers/number_one/number_one_24.svg', './font/numbers/number_one/number_one_32.svg', './font/numbers/number_one/number_one_26.svg', './font/numbers/number_one/number_one_27.svg', './font/numbers/number_one/number_one_33.svg', './font/numbers/number_one/number_one_16.svg', './font/numbers/number_one/number_one_17.svg', './font/numbers/number_one/number_one_29.svg', './font/numbers/number_one/number_one_15.svg', './font/numbers/number_one/number_one_14.svg', './font/numbers/number_one/number_one_28.svg', './font/numbers/number_one/number_one_10.svg', './font/numbers/number_one/number_one_38.svg', './font/numbers/number_one/number_one_39.svg', './font/numbers/number_one/number_one_11.svg', './font/numbers/number_one/number_one_13.svg', './font/numbers/number_one/number_one_12.svg', './font/numbers/number_one/number_one_1.svg', './font/numbers/number_one/number_one_2.svg', './font/numbers/number_one/number_one_3.svg', './font/numbers/number_one/number_one_7.svg', './font/numbers/number_one/number_one_6.svg', './font/numbers/number_one/number_one_4.svg', './font/numbers/number_one/number_one_5.svg', './font/numbers/number_four/number_four_16.svg', './font/numbers/number_four/number_four_1.svg', './font/numbers/number_four/number_four_15.svg', './font/numbers/number_four/number_four_3.svg', './font/numbers/number_four/numb ...

# %% [markdown]
# ## Convert SVG to PNG in Python
#
# 1. Create an object of Document class.
# 1. Create an object of DocumentBuilder class and initialize it with Document object.
# 1. Insert SVG image to the document using DocumentBuilder.insert_image() method.
# 1. Apply page settings to the document using DocumentBuilder.page_setup property.
# 1. Save document as PNG image using Document.save() method.

# %%
for file in files:
   # step 1
   doc = aw.Document();
   # step 2
   builder = aw.DocumentBuilder(doc);
   # step 3
   shape = builder.insert_image(file);
   # center image on page & resize propprtionally
   shape.wrap_type = aw.drawing.WrapType.NONE
   shape.relative_horizontal_position = aw.drawing.RelativeHorizontalPosition.PAGE
   shape.relative_vertical_position = aw.drawing.RelativeVerticalPosition.PAGE
   shape.horizontal_alignment = aw.drawing.HorizontalAlignment.CENTER
   shape.vertical_alignment = aw.drawing.VerticalAlignment.CENTER
   shape.width *= 2
   shape.height *= 2
   # step 4
   pageSetup = builder.page_setup
   pageSetup.page_width = 175
   pageSetup.page_height = 175
   
   # step 5
   doc.save(file[0: -4] + ".png")
